# %%
# 수열 쿼리 4
def solution(arr, queries):
    result = []
    for i in queries:
        s,e,k = i
        




solution([0, 1, 2, 4, 3], [[0, 4, 1],[0, 3, 2],[0, 3, 3]])
# Out:
# 0 4 1
# 0 3 2
# 0 3 3
