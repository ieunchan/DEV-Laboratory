# %%
"""V1"""

# def solution(today, terms, privacies):
#     # YYYY.MM.DD 형식의 날짜를 한달 28일 기준인 숫자로 변환
#     def days_func(date):
#         year, month, day = map(int,date.split('.'))
#         year_count = (12*28) * year
#         month_count = (month-1) * 28
#         return year_count + month_count + day
#     result, created_at, agree_type = [], [], []
#     # 약관 형식 & 약관 별 기간
#     term_dict = {i.split(' ')[0]:int(i.split(' ')[1])*28 for i in terms}
    
#     today = days_func(today)
#     # 유저 정보를 파싱
#     for index, value in enumerate(privacies, start=1):
#         created_at, agree_type = value.split(' ')
#         # i 유저의 최대 유효기간
#         maximum_valid_date = days_func(created_at) + term_dict[agree_type]
#         # 수집일, 최대 약관일까지는 유효함
#         if maximum_valid_date <= today:
#             result.append(index)
#     return result

"""V2"""

def to_days(date):
    year, month, day = map(int, date.split('.'))
    return (year * 28 * 12) + (month * 28) + day

def solution(today, terms, privacies):
    terms_dict = {i[0]:int(i[2:]) * 28 for i in terms}
    today = to_days(today)
    return [index for index, value in enumerate(privacies, start=1) if to_days(value[:-2]) + terms_dict[value[-1]] <= today]


solution("2022.05.19", ["A 6", "B 12", "C 3"], ["2021.05.02 A", "2021.07.01 B", "2022.02.19 C", "2022.02.20 C"]) # [1, 3]
# solution("2020.01.01", ["Z 3", "D 5"], ["2019.01.01 D", "2019.11.15 Z", "2019.08.02 D", "2019.07.01 D", "2018.12.28 Z"]) # [1, 4, 5]
# Out:
# [1, 3]
