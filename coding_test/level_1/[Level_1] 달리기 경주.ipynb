# %%
"""V1: 성능 이슈로 불가능"""

# def solution(players, callings):
#     for i in callings:
#         location = players.index(i)
#         players[location-1], players[location] = players[location], players[location-1] 
#     return players


"""V2"""

def solution(players, callings):
    position = {player:i for i, player in enumerate(players)}
    for i in callings:
        x = position[i]
        players[x-1], players[x] = players[x], players[x-1] 

        position[players[x]] = x
        position[players[x-1]] = x-1
    return sorted(position, key=position.get)

solution(["mumu", "soe", "poe", "kai", "mine"], ["kai", "kai", "mine", "mine"]) # ["mumu", "kai", "mine", "soe", "poe"]
# Out:
# ['mumu', 'kai', 'mine', 'soe', 'poe']
